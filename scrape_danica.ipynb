# %%
import requests
from bs4 import BeautifulSoup

# URL of the page to scrape
url = "https://danica.dk/privat/dine-forsikringer/faa-hurtig-hjaelp-online/din-online-laege#accordion-0-item-1"

# Send a GET request to the webpage
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad status codes

# Parse the HTML content of the page
soup = BeautifulSoup(response.content, 'html.parser')

# Extract all the text from the page
text = soup.get_text(separator='\n', strip=True)

# Print
print(text)
# Out:
# Tal med lægen
# Gå til hovedindhold
# Privat
# Erhverv
# Selvstændige
# Dit liv
# Din pension
# Dine forsikringer
# Din sundhed
# Find hjælp
# English
# Log på
# Log på
# Privat
# Netpension
# Underskriv dokumenter
# Anmeld skade
# Erhverv
# Netpension Firma (eSafeID)
# Digital signering
# Menu
# English
# Privat
# Erhverv
# Selvstændige
# Dit liv
# Din pension
# Dine forsikringer
# Din sundhed
# Find hjælp
# Book møde
# Kontakt os
# Danica
# 70 11 25 25
# Telefonsamtaler kan blive optaget og gemt
# til brug for dokumentation og sikkerhed.
# Vores linjer er åbne fra
# mandag til fredag 8.30 - 15.00
# Har du brug for behandling?
# Brug din sundhedssikring
# Har du spørgsmål, eller skal du indsende oplysninger?
# Skriv til os
# Anmeld skade
# Anmeld skade
# I Danica tager vi hånd om dig, når du har brug for støtte. Har du brug for behandling, eller er du blevet syg, skal du anmelde her.
# Anmeld skade
# Luk
# Tryk enter for at se alle resultater
# Tal med lægen
# Er dine børn syge, har du smerter, eller har du brug for at stille et hurtigt spørgsmål om familiens helbred?
# Du kan tale med lægen, så ofte du vil og få hjælp med alt fra stort til småt.
# Lægen har åbent alle dage 06.00 – 21.00 (også i weekenden)
# Book en tid
# Hvad kan online lægen hjælpe med?
# Din online læge kan  bl.a. hjælpe med:
# Lægefaglig rådgivning
# Anbefaling til videre behandling
# Fornyet recept
# Du har altid hjælpen i lommen
# Mød lægen, når det passer dig
# Direkte på mobilen eller din computer
# Det er for hele familien
# Mød lægen, når det passer dig
# Når du booker en tid, bliver du kontaktet af en læge på det tidspunkt, du ønsker. Lægerne har åbent alle dage fra 06.00-21.00 – også i weekenden. Du kan tale med lægen, når det passer dig, og du behøver ikke anmelde det til os.
# Direkte på mobilen eller din computer
# Du og din familie kan nemt tale med lægen via telefon eller videokonsultation – uanset om I er hjemme i stuen, på kontoret eller på ferie i udlandet. I har altid lægen lige ved hånden.
# Det er for hele familien
# Det er både dig, din partner og jeres børn under 24 år, der kan tale med lægen, når I har behov for det. Der gælder
#     dog særlige regler for din samlever og din partners børn.
# Spørgsmål og svar
# Hvordan kan jeg tale med sundhedseksperterne?
# Du kan tale med sundhedseksperterne ved at booke en tid i netpension eller Mobilpension app’en. Hvis du ikke allerede har Mobilpension, kan du hente den gratis i App Store eller Google Play.
# Hvordan ved jeg, om jeg har sundhedspakken?
# Du kan se, om du har sundhedspakken i netpension og i Mobilpension app’en. Når du er logget på, kan du se det på den første side, hvor der er en oversigt over din pensionsordning.
# Hvad gør jeg, hvis jeg gerne vil have sundhedspakken?
# Du kan via linket i toppen af denne side logge på netpension og tilkøbe sundhedspakken som en abonnementsløsning med betaling via MobilePay. Den koster 79 kroner om måneden.
# Danica Sundhedspakke kan tilkøbes af personer, som bor i Danmark, og som har en pensionsopsparing på minimum 25.000 kroner i Danica Pension.
# Hvordan giver jeg min familie adgang til sundhedseksperter online?
# 03d162cf-c526-4b9a-9d66-1a085ed84097
# 91e2e46c-5e18-4d66-ae77-12a561fa6e91
# For at din ægtefælle, partner eller dit barn kan benytte lægen, psykologen, diætisten. familierådgiveren og coachen, skal du registrere din
#     familie. Det gør du ved at logge ind i netpension eller Mobilpension og gå ind under, ”Gå direkte til Teladoc”. Er
#     det første gang, du besøger siden, skal du fuldføre registrering for dig og evt. din familie. Er du registreret, kan
#     du tilføje brugere under ”Min familie”.
# Herefter kan du enten booke en tid på vegne af din familie eller bede dem kontakte
#     Teladoc Health direkte på tlf. 80 83 02 52
# For børn under 18 år foregår booking og eventuel video via den forsikredes bruger.
# Vær opmærksom på, at partnere eller børn over 18 år kun kan benytte sig af telefonisk konsultation.
# Hvem er vores partner Teladoc Health?
# I samarbejde med Teladoc Health, der er blandt verdens førende inden for onlinekonsultationer, tilbyder Danica Pension et unikt netværk af læger, psykologer og diætister i et let tilgængeligt digitalt univers.
# Uanset hvilken sundhedsekspert, du kommer til at tale med, er vedkommende højt kvalificeret til at hjælpe dig og din familie. Alle læger, psykologer og diætister er både registreret hos Sundhedsstyrelsen og autoriseret inden for den type rådgivning og behandling, der tilbydes.
# Hvem kan bruge sundhedspakken? (Betingelser)
# Det er både dig, din partner og jeres børn under 24 år, der kan bruge sundhedspakken, når I har behov for det. Der gælder dog særlige regler for din samlever og din partners børn.
# Betingelser for brug af eksperterne
# Du og følgende af dine familiemedlemmer kan bruge sundhedspakken:
# din ægtefælle/registrerede partner.
# din samlever, som du har levet sammen med i et ægteskabslignende forhold på fælles bopæl i de sidste to år, før han/hun ønsker at bruge sundhedspakken.
# dine biologiske og adopterede børn mellem 0 og 24 år.
# din ægtefælles/registreredes partners biologiske og adopterede børn mellem 0 og 24 år. Barnet skal leve på fælles bopæl med dig på det tidspunkt, hvor barnet har behov for at bruge sundhedspakken.
# din samlevers biologiske og adopterede børn mellem 0 og 24 år. Barnet skal leve på fælles bopæl med dig på det tidspunkt, hvor barnet har behov for at bruge sundhedspakken. Herudover er det en betingelse, at samleveren skal have levet sammen med dig i et ægteskabslignende forhold på fælles bopæl i de sidste to år før det tidspunkt, hvor barnet har behov for at bruge sundhedspakken.
# For at have fælles bopæl skal man være registreret på samme folkeregisteradresse. For børn gælder det, at den fælles bopæl ikke anses for ophørt ved midlertidig ophold i anden bolig, hvis opholdet sker på grund af barnets uddannelse – for eksempel ophold på efterskole.
# Læs også
# Tal med psykologen
# Myldrer tankerne rundt, har du svært ved at sove, er du bekymret for dine børn eller forældre? Der kan ske mange ting, der kan vende op og ned på hverdagen. Så er det godt at have psykologen lige ved hånden.
# Læs mere
# Tal med diætisten
# Har du lyst til at tabe dig, eller har du spørgsmål til en speciel diæt, kan du booke en tid og få personlig kostvejledning af en diætist. Du og dine familiemedlemmer kan spørge om alt fra a til z – og tale med diætisten så mange gange du vil.
# Læs mere
# Få hurtig hjælp online
# Med Danica Sundhedspakke er det nemt at få hjælp og rådgivning,. Du får online adgang til en læge, psykolog, diætist, coach og familierådgiver, når det lige passer.
# Læs mere
# Meget kan ændre sig på et år. Passer din pension til dit liv?
# Tag et PensionsTjek
# For kunder
# Priser og vilkår
# Dine personoplysninger
# Jeg vil klage
# Indsend blanketter
# Whistleblowing
# Om Danica
# Kort om os
# Søg job hos Danica
# Ledelse og bestyrelse
# Presse
# Bæredygtighed
# Regnskaber
# Årsrapporter
# Finanstilsynets redegørelse
# Finansiel kalender
# Se også
# Danske Bank-koncernen
# Danica Ejendomme
# Forsikringsformidlere
# Forsikringssvindel
# Følg med på
# Hent Mobilpension appen
# LinkedIn
# Facebook
# Trustpilot
# Danica Pension, Livsforsikringsaktieselskab, Bernstorffsgade 40, 1577 København V. Tlf. 70 11 25 25, fax 45 14 96 16, CVR-nr. 24 25 61 46.
# Danica forbeholder sig alle rettigheder. Danica er under tilsyn af Finanstilsynet. Læs om,
# hvordan Danica behandler personoplysninger
# og
# information om optagelse af telefonsamtaler
# samt vores
# behandling af cookies
# og
# vilkår for brug
# .
# Du kan skrive til Danica via en sikker forbindelse:
# Hvis du skal indsende dokumenter eller har spørgsmål -
# Klik her
# Du kan også kontakte vores databeskyttelsesrådgiver med spørgsmål eller klager over persondataretlige forhold.
# Kontaktoplysningerne finder du her
# .
# Log på vores selvbetjeningsløsninger
# Log på
# Luk
# Book møde
# Kontakt os
# Danica
# 70 11 25 25
# Telefonsamtaler kan blive optaget og gemt
# til brug for dokumentation og sikkerhed.
# Vores linjer er åbne fra
# mandag til fredag 8.30 - 15.00
# Har du brug for behandling?
# Brug din sundhedssikring
# Har du spørgsmål, eller skal du indsende oplysninger?
# Skriv til os
# Anmeld skade
# Anmeld skade
# I Danica tager vi hånd om dig, når du har brug for støtte. Har du brug for behandling, eller er du blevet syg, skal du anmelde her.
# Anmeld skade
# Danicas brug af cookies og behandling af personoplysninger
# Vi bruger data fra egne cookies og tredjeparts cookies. Vi bruger dem i  kombination med dertil tilknyttede personoplysninger for at huske dine indstillinger, forbedre vores services, til at følge din brug af hjemmesiden og lave trafikmålinger samt vise de mest relevante budskaber til dig (inklusiv profilering). Nedenfor kan du vælge at sige ok til alle cookies eller selv vælge, hvilke af vores valgfrie cookies du vil acceptere. Dit samtykke dækker både over brug af cookies og den dertil tilknyttede behandling af personoplysninger. Du kan læse mere om
# brugen af cookies
# og om vores
# behandling af personoplysninger
# . I bunden af hjemmesiden kan du læse mere om, hvordan du tilbagekalder dit samtykke ved at klikke på linket om behandling af cookies.
# Nødvendige
# Disse cookies hjælper med at sikre, at vores hjemmeside fungerer ved at aktivere grundlæggende funktioner som for eksempel sidenavigation og adgang til sikre områder på hjemmesiden.
# Funktionelle
# Funktionelle cookies gør det muligt for hjemmesiden at huske dine valg af indstillinger.
# Statistiske
# Statistiske cookies gør det muligt at følge adfærden for besøgende på vores hjemmeside. Dette sker i aggregeret/anonym form, og bruges til at måle og optimere effektiviteten for vores hjemmeside.
# Marketing
# Disse cookies gør det muligt for os at identificere dig (din enhed) og profilere din adfærd, så vi kan levere det mest relevante indhold til dig.
# OK til nødvendige
# OK til valgte
# OK til alle
# Indholdet hentes
# Vis
# Skjul
# Show more rows: All table rows are already visible for screen readers.
# Show less rows: All table rows are already visible for screen readers.
